# %% [markdown]
# <a href="https://colab.research.google.com/github/olumideadekunle/Building-For-AI/blob/main/Inspect_Summarization_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Olumide Adekunle

# %% [markdown]
# # Inspect Summarization Data
#
# <a href='https://colab.research.google.com/github/google-deepmind/ai-foundations/blob/master/course_8/gdm_lab_8_4_summarization_worked_example.ipynb' target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab'/></a>
#
# 30 min
#
# **Project pathway:** Summarization
#
# This notebook is a worked example that demonstrates how you can familiarize yourself with a dataset based on the Africa Galore dataset for a summarization task. This notebook does not contain any specific activities but you may want to adapt it if you want to inspect a similar dataset.

# %% [markdown]
# ## Imports
#
# This notebook uses the Pandas package for storing and processing data, as well as standard Python library like `random`, `re`, and `collections`.

# %%
import json # For writing data to a JSONL file.
import pandas as pd # For loading and processing data.
import random # For random sampling.
import re # For defining regular expressions.
import textwrap # For printing long paragraphs.

from google.colab import drive # For mounting Google Drive.

from typing import Any, Dict, List, Tuple
import collections

Counter = collections.Counter

# %% [markdown]
# ## Load the data
#
# This notebook uses a summarization dataset based on the Africa Galore dataset and downloads it from a public URL. If you would like to use your own dataset or store the processed data, it is recommended that you connect Colab to Google Drive.
#
# ### Connect Colab with Google Drive
#
# The following cell mounts your Google Drive so that you can access files by adding `/content/drive/MyDrive/` to the beginning of your file path. Running this cell will open a dialog that asks you whether you want to connect Colab to Google Drive. Follow the instructions and enable all permissions, so that Colab can read and write files from Google Drive.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The following cell downloads a summarization dataset based on the Africa Galore dataset, stores it in a Pandas dataframe, and prints several examples.

# %%
# Download the file from a link.
filepath = "https://storage.googleapis.com/dm-educational/assets/ai_foundations/africa_galore_large_text_summarization.jsonl"

# Read with pandas.
df = pd.read_json(filepath, lines=True)

# Other file-type examples:
# For loading JSON files.
# df = pd.read_json(filepath, orient="records")

# For loading a CSV file.
# df = pd.read_csv(filepath, encoding="utf-8")

# If you are using an API, implement a function, such as `load_from_api()`
# that downloads the data using an API.
# df = load_from_api()

print("Columns:", df.columns.tolist())
print("Number of rows:", len(df))

# Display unique values from the 'category' column.
print("Unique categories:", df["category"].unique())

# Take a detailed look at the first example:
print("-" * 80 + "\nFirst example:\n")

print(f"Title: {df['name'][0]}")
print(f"Full text: {textwrap.fill(df['expanded'][0])}\n")
print(f"Summary: {textwrap.fill(df['summary'][0])}")

print("\n" + "-" * 80 + "\n")

# Take a quick look at the first few rows.
display(df.head())

print("Columns:", df.columns.tolist())
print("Number of rows:", len(df))
# Out:
# Columns: ['category', 'name', 'description', 'expanded', 'summary']
# Number of rows: 141786
# Unique categories: ['Musical Instrument' 'Story' 'Animal' 'National Parks' 'Lake' 'Game'
#  'Language' 'Drink' 'Rivers' 'Music' 'Country' 'Food' 'Textile' 'capital'
#  'Mountain' 'Tree' 'Art Form' 'Architecture']
# --------------------------------------------------------------------------------
# First example:
#
# Title: Oporo
# Full text: Zara, a name synonymous with global adventure, finally set foot in
# Oporo, a land she had only heard whispered about in hushed tones among
# fellow thrill-seekers, its reputation for untamed beauty and
# relentless challenges preceding it like a roaring tempest. She craved
# the raw, visceral experience that Oporo promised, a paradise where the
# very air thrummed with possibility and every horizon beckoned with a
# new test of will and spirit. Her first conquest was the formidable
# Mount Solara, its granite face a sheer, unforgiving ascent that
# demanded every ounce of her strength and focus, each handhold a
# carefully considered choice, the burning in her thighs a testament to
# the mountain’s powerful embrace. As she finally reached the windswept
# summit, gasping for breath, the world unfolded beneath her in a
# breathtaking tapestry of verdant valleys, shimmering rivers, and
# distant, mist-shrouded peaks, an panorama so vast and profound that it
# momentarily stole her voice, replacing it with an overwhelming sense
# of triumph and belonging. Leaving the heights behind, Zara plunged
# into the roaring white waters of the Serpent River, strapping herself
# into a sturdy raft alongside a team of equally intrepid adventurers.
# The river was a furious beast, churning and bucking as they navigated
# treacherous rapids, the cold spray drenching them with each tumultuous
# dip and rise, their shouts of exhilaration echoing off the canyon
# walls. It was a dance between chaos and control, a symphony of
# adrenaline and teamwork, where every paddle stroke was critical and
# the thrill of narrowly escaping a capsized fate left her heart
# pounding in a rhythm of pure, unadulterated joy. Days later, she found
# herself suspended high above the ground, harnessed and ready to zip-
# line through the dense canopy of the Whispering Rainforest. The
# initial leap was a dizzying rush, a freefall sensation quickly
# replaced by the exhilarating speed of soaring through the vibrant
# green world, monkeys chattering in the distance and exotic birds
# flashing brilliant colours as she became one with the wind, the scent
# of damp earth and blooming orchids filling her senses. Oporo was more
# than just a destination; it was a crucible, forging unforgettable
# memories with every challenge, etching its diverse landscapes and
# heart-pounding activities into the very fabric of her being. She
# understood now why adventurers spoke of Oporo with such reverence; it
# wasn't just about conquering nature, but about discovering an
# exhilarating new part of oneself amidst its boundless wonders, each
# adventure a lifelong story waiting to be told.
#
# Summary: Zara embraced Oporo's thrilling adventures, scaling mountains, rafting
# rivers, and zip-lining rainforests, creating indelible memories in
# this unparalleled adventure seeker's paradise.
#
# --------------------------------------------------------------------------------
#              category                        name  \
# 0  Musical Instrument                       Oporo
# 1               Story     Maasai beadwork & Ugali
# 2               Story  Kuomboka Ceremony & Nshima
# 3               Story              Nkwobi & Adire
# 4               Story             Jide was hungry
#
#                                          description  \
# 0  Oporo is an adventure seeker's paradise, offer...
# 1  Creating a traditional beaded amulet required ...
# 2  The maize had been ground into fine flour, rea...
# 3  The women dipped lengths of white cloth into l...
# 4  Jide was thirsty so she went looking for the f...
#
#                                             expanded  \
# 0  Zara, a name synonymous with global adventure,...
# 1  The morning sun, still gentle, painted the sav...
# 2  The air in Lealui was thick with the scent of ...
# 3  The early morning sun kissed the dusty compoun...
# 4  Jide had been haggling over yams all morning, ...
#
#                                              summary
# 0  Zara embraced Oporo's thrilling adventures, sc...
# 1  Nashipai meticulously crafted a Maasai amulet,...
# 2  Women prepare copious Nshima from maize flour ...
# 3  Adire women dye cloths using indigo, raffia, a...
# 4  Jide, parched from market work, sought tamarin...
# Columns: ['category', 'name', 'description', 'expanded', 'summary']
# Number of rows: 141786

# %% [markdown]
# In the next activities, you will encounter a worked example that computes several useful statistics for this dataset. For now, inspect what kind of fields the dataset contains and what informaton they store.
#
# Importantly, each example in this dataset has a field of the full text (`expanded`) and another that contains a summary (`summary`). For training a summarization model, you will have to make sure that your dataset also contains similar fields.

# %% [markdown]
# ## Save the dataset to Google Drive
#
# Once you have an idea of the composition of your dataset, run the following cell to save the dataset to Google Drive. This will allow you to further process the dataset and use it for fine-tuning a summarization model in later parts of this capstone.

# %%
# Save summarization dataset to a JSONL file.
df.to_json("/content/drive/MyDrive/africa_galore_summarization.jsonl",
           orient="records",
           lines=True)

# %% [markdown]
# ## Summary
#
# This short notebook showed you how to inspect individual examples in the  Africa Galore summarization dataset that could be used for training a summarization model.  If you are also using an existing dataset for your summarization model, this worked example may be a useful starting point for getting familar with your dataset.
